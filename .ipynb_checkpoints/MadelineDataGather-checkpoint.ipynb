# %%
import os
import pandas as pd
import csv

csvpath = "../parking-citations.csv"

with open(csvpath, newline='') as csvfile:

    # CSV reader specifies delimiter and variable that holds contents
    csvreader = csv.reader(csvfile, delimiter=',')

    print(csvreader)

    # Read the header row first (skip this step if there is now header)
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")
# Out:
# <_csv.reader object at 0x000001A01494B6C8>
# CSV Header: ['Ticket number', 'Issue Date', 'Issue time', 'Meter Id', 'Marked Time', 'RP State Plate', 'Plate Expiry Date', 'VIN', 'Make', 'Body Style', 'Color', 'Location', 'Route', 'Agency', 'Violation code', 'Violation Description', 'Fine amount', 'Latitude', 'Longitude']

# %%
file = "../parking-citations.csv"
violations_df = pd.read_csv(file)
violations_df.head()
# Out:
# C:\Users\madel\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (0,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 0    1103341116  2015-12-21T00:00:00      1251.0      NaN          NaN
# 1    1103700150  2015-12-21T00:00:00      1435.0      NaN          NaN
# 2    1104803000  2015-12-21T00:00:00      2055.0      NaN          NaN
# 3    1104820732  2015-12-26T00:00:00      1515.0      NaN          NaN
# 4    1105461453  2015-09-15T00:00:00       115.0      NaN          NaN
#
#   RP State Plate  Plate Expiry Date  VIN  Make Body Style Color  \
# 0             CA           200304.0  NaN  HOND         PA    GY
# 1             CA           201512.0  NaN   GMC         VN    WH
# 2             CA           201503.0  NaN  NISS         PA    BK
# 3             CA                NaN  NaN  ACUR         PA    WH
# 4             CA           200316.0  NaN  CHEV         PA    BK
#
#              Location  Route  Agency Violation code Violation Description  \
# 0     13147 WELBY WAY  01521     1.0         4000A1    NO EVIDENCE OF REG
# 1       525 S MAIN ST   1C51     1.0         4000A1    NO EVIDENCE OF REG
# 2       200 WORLD WAY    2R2     2.0           8939            WHITE CURB
# 3       100 WORLD WAY   2F11     2.0            000                17104h
# 4  GEORGIA ST/OLYMPIC  1FB70     1.0          8069A  NO STOPPING/STANDING
#
#    Fine amount   Latitude  Longitude
# 0         50.0    99999.0    99999.0
# 1         50.0    99999.0    99999.0
# 2         58.0  6439997.9  1802686.4
# 3          NaN  6440041.1  1802686.2
# 4         93.0    99999.0    99999.0

# %%
violations_df.describe()
# Out:
#          Issue time    Marked Time  Plate Expiry Date        Agency  \
# count  9.149713e+06  302937.000000       8.315710e+06  9.151876e+06
# mean   1.201837e+03    1055.520356       1.872249e+05  5.199459e+01
# std    4.733818e+02     227.334047       5.205391e+04  9.347935e+00
# min    0.000000e+00       1.000000       1.000000e+00  1.000000e+00
# 25%    9.110000e+02     910.000000       2.016020e+05  5.100000e+01
# 50%    1.154000e+03    1036.000000       2.017030e+05  5.400000e+01
# 75%    1.509000e+03    1200.000000       2.018050e+05  5.500000e+01
# max    2.359000e+03    2400.000000       9.201020e+05  9.700000e+01
#
#         Fine amount      Latitude     Longitude
# count  9.145597e+06  9.152448e+06  9.152448e+06
# mean   7.012290e+01  5.515342e+06  1.590543e+06
# std    3.213979e+01  2.963743e+06  2.020136e+06
# min    1.000000e+01  9.999900e+04  9.999900e+04
# 25%    6.300000e+01  6.421759e+06  1.821893e+06
# 50%    6.800000e+01  6.451849e+06  1.842072e+06
# 75%    7.300000e+01  6.475075e+06  1.858208e+06
# max    5.050000e+02  4.042322e+09  4.042322e+09

# %%
violations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9152451 entries, 0 to 9152450
# Data columns (total 19 columns):
# Ticket number            object
# Issue Date               object
# Issue time               float64
# Meter Id                 object
# Marked Time              float64
# RP State Plate           object
# Plate Expiry Date        float64
# VIN                      object
# Make                     object
# Body Style               object
# Color                    object
# Location                 object
# Route                    object
# Agency                   float64
# Violation code           object
# Violation Description    object
# Fine amount              float64
# Latitude                 float64
# Longitude                float64
# dtypes: float64(7), object(12)
# memory usage: 1.3+ GB

# %%
violations_df['Color'].unique()
# Out:
# array(['GY', 'WH', 'BK', 'BL', 'BR', 'SI', 'GO', nan, 'RE', 'MA', 'TA',
#        'BU', 'GR', 'YE', 'OR', 'WT', 'RD', 'SL', 'BN', 'OT', 'GN', 'MR',
#        'BG', 'PR', 'TN', 'UN', 'PK', 'TU', 'CO', 'BE', 'RU', 'PU', 'PL',
#        'CR', 'SN', 'PE', 'BZ', 'PI', 'ME', 'CH', 'TE', 'LI', 'MU', 'KH',
#        'GA', 'AQ', 'WI', 'OL', 'SA', 'KA', 'RS', 'CL', 'TP', 'PW', 'SU',
#        'CP', 'UT', 'SH', 'OG', 'UK', 'VI', 'BW', 'RV', 'YL', 'TW', 'GD',
#        'DA', 'W', 'BC', 'TL', 'MY', 'EF', 'WE', 'AU', 'WR', 'WA', 'AM',
#        'GL', 'RA', 'BI', 'BA', 'ES', 'LA', 'PP', 'GE', 'VA', 'LE', 'CA',
#        'SV', 'BH', 'AP', 'VO', 'VU', 'SM', 'TR', 'O', 'R', 'IN', 'MN',
#        'IV', 'MP', 'AD', 'MD', 'SO', 'CU', 'MC', 'MI', 'MO', 'BD', 'EG',
#        'LP'], dtype=object)

# %%
violations_df['RP State Plate'].value_counts()
# Out:
# CA    8524570
# AZ      81518
# TX      57975
# NV      54390
# FL      39917
# WA      36146
# IL      26070
# OR      25577
# CO      23302
# NY      17006
# PA      13436
# UT      13042
# MI      12871
# OH      12584
# NJ      12264
# GA      12260
# TN      11905
# IN      11801
# VA      11016
# MA       9843
# MO       9470
# MD       9389
# OK       9200
# NC       9059
# MN       8895
# NM       8647
# MX       7720
# LA       6777
# WI       6163
# CT       5478
#        ...
# RI       1372
# DC       1342
# AK       1211
# SD       1207
# DE       1012
# ND        972
# VT        850
# QU        782
# WV        732
# DD        504
# US        433
# FN        385
# NB        183
# CN        175
# MB        159
# SA        152
# XX        134
# NS         71
# CZ         37
# VI         35
# GU         26
# PR         23
# PE         19
# NW         18
# TT         18
# AS         17
# NF         14
# YU         10
# |           2
# ML          1
# Name: RP State Plate, Length: 78, dtype: int64

# %%
violations_df['RP State Plate']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-529db950e260> in <module>
# ----> 1 violations_df['RP State Plate'].info()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
violations_df['Marked Time'].value_counts
# Out:
# 800.0     15695
# 900.0      4585
# 1100.0     4559
# 1000.0     4509
# 830.0      3872
# 930.0      3859
# 1130.0     3457
# 1030.0     3430
# 1110.0     3042
# 1115.0     2888
# 1040.0     2860
# 1050.0     2844
# 1055.0     2810
# 1045.0     2745
# 815.0      2724
# 1020.0     2710
# 820.0      2699
# 945.0      2698
# 805.0      2646
# 940.0      2622
# 1145.0     2603
# 1200.0     2541
# 1120.0     2521
# 840.0      2507
# 1015.0     2504
# 955.0      2453
# 920.0      2444
# 845.0      2441
# 950.0      2416
# 1105.0     2410
#           ...
# 2026.0        1
# 2024.0        1
# 2023.0        1
# 2327.0        1
# 1657.0        1
# 253.0         1
# 344.0         1
# 2142.0        1
# 2236.0        1
# 342.0         1
# 2232.0        1
# 2226.0        1
# 332.0         1
# 331.0         1
# 2318.0        1
# 328.0         1
# 2225.0        1
# 2221.0        1
# 2215.0        1
# 2212.0        1
# 314.0         1
# 313.0         1
# 2210.0        1
# 2201.0        1
# 307.0         1
# 2159.0        1
# 302.0         1
# 301.0         1
# 2144.0        1
# 2316.0        1
# Name: Marked Time, Length: 1226, dtype: int64

# %%
#droppping any row that has a null value gives us no rows

clean_vio_df = violations_df.dropna(how="any")
clean_vio_df.count()
# Out:
# Ticket number            0
# Issue Date               0
# Issue time               0
# Meter Id                 0
# Marked Time              0
# RP State Plate           0
# Plate Expiry Date        0
# VIN                      0
# Make                     0
# Body Style               0
# Color                    0
# Location                 0
# Route                    0
# Agency                   0
# Violation code           0
# Violation Description    0
# Fine amount              0
# Latitude                 0
# Longitude                0
# dtype: int64

# %%
grouped_vio_df = violations_df.groupby(['Violation Description'])
# Out:
#         Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 0          1103341116  2015-12-21T00:00:00      1251.0      NaN          NaN
# 1          1103700150  2015-12-21T00:00:00      1435.0      NaN          NaN
# 2          1104803000  2015-12-21T00:00:00      2055.0      NaN          NaN
# 3          1104820732  2015-12-26T00:00:00      1515.0      NaN          NaN
# 4          1105461453  2015-09-15T00:00:00       115.0      NaN          NaN
# 5          1106226590  2015-09-15T00:00:00        19.0      NaN          NaN
# 6          1106500452  2015-12-17T00:00:00      1710.0      NaN          NaN
# 7          1106500463  2015-12-17T00:00:00      1710.0      NaN          NaN
# 8          1106506402  2015-12-22T00:00:00       945.0      NaN          NaN
# 9          1106506413  2015-12-22T00:00:00      1100.0      NaN          NaN
# 10         1106506424  2015-12-22T00:00:00      1100.0      NaN          NaN
# 11         1106506435  2015-12-22T00:00:00      1105.0      NaN          NaN
# 12         1106506446  2015-12-22T00:00:00      1110.0      NaN          NaN
# 13         1106549754  2015-12-15T00:00:00       825.0      NaN          NaN
# 14         1107179581  2015-12-27T00:00:00      1055.0      NaN          NaN
# 15         1107179592  2015-12-27T00:00:00      1200.0      NaN          NaN
# 16         1107179603  2015-12-27T00:00:00      1400.0      NaN          NaN
# 17         1107539823  2015-09-16T00:00:00      2120.0      NaN          NaN
# 18         1107539834  2015-09-16T00:00:00      1045.0      NaN          NaN
# 19         1107780811  2015-12-22T00:00:00      1102.0      NaN          NaN
# 20         1107780822  2015-12-22T00:00:00      1105.0      NaN          NaN
# 24         1108311002  2015-12-22T00:00:00       140.0      NaN          NaN
# 25         1108311013  2015-12-22T00:00:00       150.0      NaN          NaN
# 26         1108311024  2015-12-22T00:00:00       205.0      NaN          NaN
# 27         1108311035  2015-12-22T00:00:00       200.0      NaN          NaN
# 28         1108311046  2015-12-22T00:00:00       225.0      NaN          NaN
# 29         1108311050  2015-12-22T00:00:00       510.0      NaN          NaN
# 33         1108321723  2015-12-21T00:00:00      1041.0      NaN          NaN
# 37         1109056185  2015-12-28T00:00:00      1938.0     WF55          NaN
# 15                  CA           201602.0  NaN  MBNZ         PA    BK
# 16                  CA           201611.0  NaN  NISS         PA    WH
# 17                  CA           201502.0  NaN  NISS         PA   NaN
# 18                  CA                NaN  NaN  CHEV         PA    BK
# 19                  CA           201606.0  NaN  HOND         PA    BK
# 20                  FL           201611.0  NaN  FORD         PA    WH
# 24                  CA           201603.0  NaN  FORD         PA    RE
# 25                  CA           201610.0  NaN  FORD         SU    GY
# 26                  CA           201607.0  NaN  MASE         PA    BL
# 27                  CA           201511.0  NaN   BMW         PA    BK
# 28                  CA           201512.0  NaN  PONT         PA    SI
# 29                  CA           201601.0  NaN  TESL         PA    GY
# 33                  CA           201610.0  NaN  HOND         PA    BK
# 37                  CA           201512.0  NaN  ACUR         PA    GY
# 38                  CA                NaN  NaN  TOYO         PA    GY
# ...                ...                ...  ...   ...        ...   ...
# 8972195             CA           201910.0  NaN  NISS         PA    SI
# 8972542             CA           201904.0  NaN  HOND         PA    WH
# 8972543             FL           201906.0  NaN  MBNZ         PA    WH
# 8988155             CA           201911.0  NaN   KIA         PA    BK
# 8988156             NC           201905.0  NaN  CHRY         PA    BK
# 9005985             TN                NaN  NaN   NaN        NaN    YE
# 9005986             TN                NaN  NaN   NaN        NaN    YE
# 9006051             VA           201910.0  NaN  KOTI         TL    WH
# 9013615             CA           201906.0  NaN  MITS         PA    BK
# 9034270             CA           201809.0  NaN  TOYO         PA    GY
# 9034300             CA           201909.0  NaN  MNNI         PA    BL
# 9034482             CA           201901.0  NaN  FORD         PA    WH
# 9034483             CA           201910.0  NaN   KIA         PA    WH
# 9043696             CA           201807.0  NaN  TOYO         PA    WH
# 9043724             CA                NaN  NaN  TOYO         PA    WH
# 9052615             CA           201906.0  NaN  BUIC         PA    GY
# 9052616             CA           201901.0  NaN  FORD         PA   NaN
# 9070773             TN                NaN  NaN   NaN        NaN    YE
# 9070893             CA           200315.0  NaN  HURR         RV    WH
# 9078640             CA                NaN  NaN  CHEV         TR    BK
# 9078679             CA           202001.0  NaN  MINI         PA    GY
# 9078818             CA           201909.0  NaN  FORD         SU    BK
# 9087182             CA           201908.0  NaN  NISS         PA    SI
# 9094696             CA           201908.0  NaN  CHEV         RV    WH
# 9102209             CA           201909.0  NaN   BMW         PA    WH
# 9102489             CA           201909.0  NaN  TOYO         PA    BR
# 9111190             CA           200120.0  NaN  ACUR         PA    RE
# 9111403             CA           201912.0  NaN  HOND         PA    RE
# 9111404             CA           201909.0  NaN  HOND         PA    BL
# 9144885             CA           200919.0  NaN   NaN         PA    WH
#
#                      Location  Route  Agency Violation code  \
# 0             13147 WELBY WAY  01521     1.0         4000A1
# 1               525 S MAIN ST   1C51     1.0         4000A1
# 2               200 WORLD WAY    2R2     2.0           8939
# 3               100 WORLD WAY   2F11     2.0            000
# 4          GEORGIA ST/OLYMPIC  1FB70     1.0          8069A
# 5          SAN PEDRO S/O BOYD  1A35W     1.0         4000A1
# 6             SUNSET/ALVARADO  00217     1.0           8070
# 7             SUNSET/ALVARADO  00217     1.0           8070
# 8              721 S WESTLAKE   2A75     1.0         8069AA
# 9             1159 HUNTLEY DR   2A75     1.0         8069AA
# 10            1159 HUNTLEY DR   2A75     1.0         8069AA
# 11            1159 HUNTLEY DR   2A75     1.0         8069AA
# 12             1200 W MIRAMAR   2A75     1.0         4000A1
# 13                  4TH/STATE   CM96     1.0          8069A
# 14       3100 N HOLLYRIDGE DR    NaN    54.0          8058L
# 15          3115 N BERENDO DR    NaN    54.0          8058L
# 16        3100 N BEACHWOOD DR    NaN    54.0          8058L
# 17             BLAINE/11TH PL  1FB95     1.0         4000A1
# 18         1246 S FIGUEROA ST   1L20     1.0         8069AP
# 19              PLATA/RAMPART    2A1     1.0          8069B
# 20                        NaN    2A1     1.0          8069B
# 24           12113 BURBANK BL  01532     1.0          5200A
# 25              6936 AGNES AV  01514     1.0          5200A
# 26           12036 SATICOY ST  01503     1.0          5200A
# 27         7466 LAUREL CYN BL  01503     1.0            099
# 28       BURBANK BL/COLFAX AV  01535     1.0          5200A
# 29       11411 DONA PEGITA DR    NaN     1.0          5200A
# 33             10635 FRIAR ST  15EL5     1.0         8056E4
# 37            100 S HARPER AV  00472    54.0          8813B
# 38               100 S HARPER  00472    54.0          8813B
# ...                       ...    ...     ...            ...
# 8972195  2800 EAST OBSERVATOR    NaN     4.0            000
# 8972542   3160 CANYON LAKE DR    NaN     4.0            000
# 8972543   3160 CANYON LAKE DR    NaN     4.0            000
# 8988155    WESTERN CYN RD N/O    NaN     4.0            000
# 8988156  2800 EAST OBSERVATOR    NaN     4.0            000
# 9005985       920 MURDOCK AVE  5SL17     1.0            000
# 9005986       920 MURDOCK AVE  5SL17     1.0            000
# 9006051  GLENOAKS/S/O SHELDON   CM89     1.0            000
# 9013615    S/W/C MANHATTAN PL  00677     1.0            000
# 9034270        1130 S VERMONT   20V3     1.0          22511
# 9034300  1ST ST/ASTRONAUT ELI     1A     1.0            000
# 9034482         11559 E 114TH  18H41     1.0            000
# 9034483         1242 E 115 ST  18H41     1.0            000
# 9043696        929 ACADEMY RD    NaN     4.0            000
# 9043724    WESTERN CYN RD S/O    NaN     4.0            000
# 9052615   39TH ST/WESTERN AVE  00375     1.0          22511
# 9052616   39TH ST/WESTERN AVE  00375     1.0          22511
# 9070773      D ST/BANNING AVE  5SL17     1.0            000
# 9070893   LANKERSHIM BL/ERWIN  01526     1.0            000
# 9078640  21211 AVENUE SAN LUI  21X98     1.0            000
# 9078679  500 BUENA VISTA VIEW    NaN     4.0            000
# 9078818         401 E 40TH PL  13A41     1.0            000
# 9087182  500 PUNTA VISTA VIEW    NaN     4.0            000
# 9094696   WILBUR N/O NORDHOFF  01785     1.0            000
# 9102209  5333 ZOO DR (FAR NOR    NaN     1.0            000
# 9102489   SYCAMORE AV/MELROSE    WTD     1.0            000
# 9111190  ACADEMY RD-ELYSIAN P    NaN     4.0            000
# 9111403  929 ACADEMY RD/ELYSI    NaN     4.0            000
# 9111404      BUENA VISTA HILL    NaN     4.0            000
# 9144885          9303 FLICKER    NaN    54.0            020
#
#         Violation Description  Fine amount      Latitude     Longitude
# 0          NO EVIDENCE OF REG         50.0  9.999900e+04  9.999900e+04
# 1          NO EVIDENCE OF REG         50.0  9.999900e+04  9.999900e+04
# 2                  WHITE CURB         58.0  6.439998e+06  1.802686e+06
# 3                      17104h          NaN  6.440041e+06  1.802686e+06
# 4        NO STOPPING/STANDING         93.0  9.999900e+04  9.999900e+04
# 9102209                6433K7          NaN  6.475382e+06  1.876992e+06
# 9102489                22651J          NaN  9.999900e+04  9.999900e+04
# 9111190               5749884          NaN  9.999900e+04  9.999900e+04
# 9111403               5749088          NaN  6.490021e+06  1.851461e+06
# 9111404               5749088          NaN  9.999900e+04  9.999900e+04
# 9144885                22504A         63.0  9.999900e+04  9.999900e+04
#
# [2436 rows x 19 columns]

# %%
#clean time

violations_df['Date_Clean'] =violations_df['Issue Date'].str.slice(0, 10)
#violations_df.head()

#prepping set for violations by percentages


vio_type_df = violations_df[['Date_Clean', 'Violation code', 'Violation Description', 'Fine amount']].sort_values(by=['Date_Clean'])
vio_type_df.head()
# Out:
#          Date_Clean Violation code Violation Description  Fine amount
# 107223   2010-01-09          80732       EXCEED 72 HOURS          NaN
# 8770002  2010-01-09          5204A          EXPIRED TAGS         25.0
# 6868664  2010-02-03           8606       PK OTSD PSTD AR          NaN
# 4826069  2010-03-09           8603       PK IN PROH AREA          NaN
# 786475   2010-04-27            011                22500F          NaN

# %%
vio_type_df['Violation Description']
# Out:
# 107223                    EXCEED 72 HOURS
# 8770002                      EXPIRED TAGS
# 6868664                   PK OTSD PSTD AR
# 4826069                   PK IN PROH AREA
# 786475                             22500F
# 2109415                    WRG SD/NOT PRL
# 898468                           RED ZONE
# 7574789                NO EVIDENCE OF REG
# 1063545                        NO PARKING
# 1013018              NO PARK/STREET CLEAN
# 2285648                          RED ZONE
# 1106345                      EXPIRED TAGS
# 7735583                              5200
# 5606557                             22514
# 2593517              NO PARK/STREET CLEAN
# 3893459                          RED ZONE
# 2992110                          RED CURB
# 6167407                      PREF PARKING
# 3975608                  NO STOP/STAND PM
# 8396400                        WHITE CURB
# 8351333                  NO STOP/STAND PM
# 4100874                        WHITE CURB
# 6165437                        NO PARKING
# 8336456                            22502A
# 8360085              NO PARK/STREET CLEAN
# 6166842                        WHITE ZONE
# 8449466                   PK IN PROH AREA
# 8588481              PARK IN GRID LOCK ZN
# 8748136                      EXPIRED TAGS
# 173009                           RED ZONE
#                         ...
# 8759527              NO PARK/STREET CLEAN
# 8759528              NO PARK/STREET CLEAN
# 8761467                          RED ZONE
# 8761529              NO PARK/STREET CLEAN
# 8761555              PREFERENTIAL PARKING
# 9040462    NO STOPPING/ANTI-GRIDLOCK ZONE
# 9051207              NO PARK/STREET CLEAN
# 9051212              NO PARK/STREET CLEAN
# 9051266              NO PARK/STREET CLEAN
# 9051271                        WHITE ZONE
# 9051279              NO PARK/STREET CLEAN
# 9051327              NO PARK/STREET CLEAN
# 9051328              NO PARK/STREET CLEAN
# 9051418              NO PARK/STREET CLEAN
# 9051423                   EXCEED 72HRS-ST
# 9051424                        METER EXP.
# 9051495                          RED ZONE
# 9051836              NO PARK/STREET CLEAN
# 9051875              OFF STR/OVERTIME/MTR
# 9052003                          RED ZONE
# 9052193              PREFERENTIAL PARKING
# 9052194                        METER EXP.
# 9052282                   DISPLAY OF TABS
# 9052499              NO PARK/STREET CLEAN
# 9052581              NO PARK/STREET CLEAN
# 9052584                        METER EXP.
# 9052585              NO PARK/STREET CLEAN
# 9061802              NO PARK/STREET CLEAN
# 9061803              NO PARK/STREET CLEAN
# 9145349                        METER EXP.
# Name: Violation Description, Length: 9152451, dtype: object
